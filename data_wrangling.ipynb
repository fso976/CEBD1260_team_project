# %%
# import the library
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set() 

# convert scientific notation to decimals
pd.set_option('display.float_format', lambda x: '%.2f' % x)

df = pd.read_csv('BlackFriday.csv')

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 nan                 nan      8370
# 1                6.00               14.00     15200
# ...

# %% [markdown]
# #### Summarizing data for inspection

# %%
print('### Blackfriday summary ###')
print(df.columns)
print('\n')
print(df.head())
print('\n')
print('***************************************************************************')
print('\n')
print(df.describe())
print('\n')
print("Shape of dataframe")
df.shape
# Out:
# ### Blackfriday summary ###
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')
#
#
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# ...

# %%
df['User_ID'] = df['User_ID'].astype(str)
df.dtypes
# Out:
# User_ID                        object
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df.sort_values(by='Purchase', ascending = False)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 87440   1001474  P00052842      M  26-35           4             A
# 93016   1002272  P00052842      M  26-35           0             C
# 370891  1003160  P00052842      M  26-35          17             C
# 349658  1005848  P00119342      M  51-55          20             A
# 503697  1005596  P00117642      M  36-45          12             B
# 292083  1003045  P00052842      M  46-50           1             B
# 321782  1001577  P00052842      M    55+           0             C
# 437804  1001387  P00086242      F  51-55          13             B
# 298378  1003947  P00116142      M  26-35           0             C
# 373300  1003511  P00085342      M  51-55           0             C
# 7542    1001178  P00116142      M    55+           0             C
# 229329  1005367  P00085342      M  18-25           4             A
# 416883  1004117  P00161842      M  18-25           4             B
# ...

# %%
df[df['Age'] == '55+']
# Out:
#         User_ID Product_ID Gender  Age  Occupation City_Category  \
# 4       1000002  P00285442      M  55+          16             C
# 159     1000031  P00117442      M  55+           7             C
# 160     1000031  P00322042      M  55+           7             C
# 161     1000031  P00216342      M  55+           7             C
# 162     1000031  P00329342      M  55+           7             C
# 451     1000080  P00157542      M  55+           1             C
# 452     1000080  P00293242      M  55+           1             C
# 453     1000080  P00064042      M  55+           1             C
# 475     1000089  P00223942      F  55+           9             C
# 476     1000089  P00362342      F  55+           9             C
# 477     1000090  P00027542      M  55+          13             C
# 478     1000090  P00051442      M  55+          13             C
# 479     1000090  P00234842      M  55+          13             C
# ...

# %%
df.groupby(by='Age')['Purchase'].sum()
# Out:
# Age
# 0-17      132659006
# 18-25     901669280
# 26-35    1999749106
# 36-45    1010649565
# 46-50     413418223
# 51-55     361908356
# 55+       197614842
# Name: Purchase, dtype: int64

# %%
df[df['Gender'] == 'F']
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 14      1000006  P00231342      F  51-55           9             A
# 15      1000006  P00190242      F  51-55           9             A
# 16      1000006   P0096642      F  51-55           9             A
# 17      1000006  P00058442      F  51-55           9             A
# 29      1000010  P00085942      F  36-45           1             B
# 30      1000010  P00118742      F  36-45           1             B
# 31      1000010  P00297942      F  36-45           1             B
# 32      1000010  P00266842      F  36-45           1             B
# 33      1000010  P00058342      F  36-45           1             B
# ...

# %%
df.groupby(by='City_Category')['Purchase'].sum()
# Out:
# City_Category
# A    1295668797
# B    2083431612
# C    1638567969
# Name: Purchase, dtype: int64

# %%
df.groupby(by=['Age','Stay_In_Current_City_Years'])['Purchase'].sum()
# Out:
# Age    Stay_In_Current_City_Years
# 0-17   0                              19935752
#        1                              44180841
#        2                              29465710
#        3                              24798806
#        4+                             14277897
# 18-25  0                             145726349
#        1                             291558752
#        2                             178189274
#        3                             140378016
#        4+                            145816889
# 26-35  0                             250550248
#        1                             708717271
#        2                             366893047
#        3                             356373439
#        4+                            317215101
# 36-45  0                             130253419
#        1                             333213862
#        2                             192549171
#        3                             213489557
# ...

# %%
df.groupby(by=['Age', 'Gender'])['Purchase'].mean().round()
# Out:
# Age    Gender
# 0-17   F        8445.00
#        M        9312.00
# 18-25  F        8405.00
#        M        9507.00
# 26-35  F        8792.00
#        M        9471.00
# 36-45  F        9047.00
#        M        9517.00
# 46-50  F        8929.00
#        M        9429.00
# 51-55  F        9131.00
#        M        9789.00
# 55+    F        9120.00
#        M        9557.00
# Name: Purchase, dtype: float64

# %% [markdown]
# #### Men on average spend more on Black Friday across all age groups.

# %%
df.groupby(by='Gender')['Purchase'].sum()
# Out:
# Gender
# F    1164624021
# M    3853044357
# Name: Purchase, dtype: int64

# %%
df.groupby(by=['Age', 'City_Category'])['Purchase'].mean().round()
# Out:
# Age    City_Category
# 0-17   A                8673.00
#        B                8985.00
#        C                9172.00
# 18-25  A                8887.00
#        B                9070.00
#        C                9820.00
# 26-35  A                8990.00
#        B                9199.00
#        C                9953.00
# 36-45  A                9042.00
#        B                9150.00
#        C               10009.00
# 46-50  A                8386.00
#        B                9297.00
#        C                9662.00
# 51-55  A                9575.00
#        B                9394.00
#        C                9918.00
# 55+    A                8587.00
#        B                9886.00
#        C                9523.00
# Name: Purchase, dtype: float64
